# %% [markdown]
# # Dataset for embeddings
# Let's scrape from 1000 to 1500 comments for each initial dataset class.

# %%
import kaggle
import os
import pandas as pd

# %%
# kaggle datasets download -d theshadow29/subreddit-classification
try:
    os.mkdir("dataset")
except FileExistsError:
    print("Directory already exists")
kaggle.api.authenticate()
kaggle.api.dataset_download_files("theshadow29/subreddit-classification", path="dataset", unzip=True)

# %%
dataset = pd.read_csv('dataset/fine_grained_full.csv')
dataset.shape

# %%
dataset.head()

# %%
import datetime as dt
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import lxml
import cchardet
import time

start_date = int(dt.datetime(2017, 1, 1, 0, 0).timestamp())
end_date = int(dt.datetime(2019, 1, 1, 0, 0).timestamp())
limit_per_subreddit = 1500
pages_per_sub = 40
subreddits = dataset["label"].unique()
try:
    os.mkdir("reddit_comments")
except FileExistsError:
    print("Directory already exists")
subreddits.shape

# %%
def pull_page(subreddit):
    titles = []
    url = f"https://old.reddit.com/r/{subreddit}/"
    requests_session = requests.Session()
    headers = {'User-Agent': 'Mozilla/5.0'}
    for i in range(pages_per_sub):
        if (i % 5 == 4):
            time.sleep(2)
        page = requests_session.get(url, headers=headers)
        soup = BeautifulSoup(page.text, 'lxml')
        attrs = {'class': 'thing'}
        for post in soup.find_all('div', attrs=attrs):
            titles.append(post.find('p', class_="title").text)
        next_button = soup.find("span", class_="next-button")
        try:
            url = next_button.find("a").attrs['href']
        except:
            print(f"{subreddit} page {i}")
            break
        
    return (subreddit, titles)

# %%
from multiprocessing.pool import ThreadPool
start = dt.datetime.now()
for chunk in tqdm(range(0, 1401, 40)):
    with ThreadPool(40) as pool:
        for subreddit, result in pool.map(pull_page, subreddits[chunk:min(chunk + 40, 1430)]):
            df = pd.DataFrame(result)
            df.to_csv(f"reddit_comments{os.path.sep}{subreddit}.csv", index=False)
        time.sleep(2)
passed = dt.datetime.now() - start
print(passed)

# %%
pull_page(subreddits[0])

# %% [markdown]
# I failed to parse subreddits as there were too little titles available and the data was too noisy as well. I managed to parse 90 mib of data but of course that wasn't nearly enough to train decent embedding. At the same time my attempts to use pushshift api failed as there was a problem on their side (api returned only super small fraction of each query.
#
# But luckily I found pretrained glove word embeddings trained on more than 250 gib of reddit data. So I'm willing to test if they are good enough.

# %%
import numpy as np
import io
from tqdm.notebook import tqdm
# Number of words - 1623397 
# word_part = ["" for i in range(1623397)]
# number_part = np.empty((1623397, 300), dtype=np.float32)
embeddings = {}
with io.open("GloVe.Reddit.120B.300D.txt", "r", encoding='utf-8') as file:
    file.readline()
    for i, line in tqdm(enumerate(file)):
        values = line.split(' ');
#         word_part[i] = values[0]
#         number_part[i] = np.asarray(values[1:], "float32")
        embeddings[values[0]] = np.asarray(values[1:], "float32")

# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)

# %%
number_part.shape

# %%
# https://www.kaggle.com/leighplt/glove-reddit-comments
from scipy import spatial
def test_embeddings_wordsim(embeddings):
    av_abs_dev = 0.0
    file_len = sum(1 for line in open('wordsim353_sim_rel/wordsim_relatedness_goldstandard.txt'))
    with open("wordsim353_sim_rel/wordsim_relatedness_goldstandard.txt") as file:
        for line in file:
            values = line.split()
            print(values[0], values[1], values[2])
            simil = float(values[2]) / 10.0
            cos_sim = 1 - spatial.distance.cosine(embeddings[values[0]], embeddings[values[1]])
            print(f"Accordings to embeddings {cos_sim}")
            av_abs_dev += abs(cos_sim - simil)
    print(f"Final average abs deviation: {av_abs_dev / float(file_len)}")

# %%
test_embeddings_wordsim(embeddings)
# Out:
# computer keyboard 7.62
# Accordings to embeddings 0.5736358761787415
# Jerusalem Israel 8.46
# Accordings to embeddings 0.6853241920471191
# planet galaxy 8.11
# Accordings to embeddings 0.7235155701637268
# canyon landscape 7.53
# Accordings to embeddings 0.33178621530532837
# OPEC country 5.63
# Accordings to embeddings 0.26875486969947815
# day summer 3.94
# Accordings to embeddings 0.6057249903678894
# day dawn 7.53
# Accordings to embeddings 0.48720410466194153
# country citizen 7.31
# Accordings to embeddings 0.6312815546989441
# planet people 5.75
# Accordings to embeddings 0.4247969388961792
# environment ecology 8.81
# Accordings to embeddings 0.445987343788147
# Maradona football 8.62
# Accordings to embeddings 0.3413398563861847
# OPEC oil 8.59
# Accordings to embeddings 0.42219042778015137
# money bank 8.50
# Accordings to embeddings 0.6444064378738403
# computer software 8.50
# Accordings to embeddings 0.7147970199584961
# law lawyer 8.38
# Accordings to embeddings 0.6398980021476746
# weather forecast 8.34
# Accordings to embeddings 0.6526373624801636
# network hardware 8.31
# Accordings to embeddings 0.5074180960655212
# nature environment 8.31
# Accordings to embeddings 0.5856153964996338
# FBI investigation 8.31
# Accordings to embeddings 0.7797407507896423
# money wealth 8.27
# Accordings to embeddings 0.6454237699508667
# psychology Freud 8.21
# Accordings to embeddings 0.4884234070777893
# news report 8.16
# Accordings to embeddings 0.6059321761131287
# war troops 8.13
# Accordings to embeddings 0.6030900478363037
# physics proton 8.12
# Accordings to embeddings 0.30002138018608093
# bank money 8.12
# Accordings to embeddings 0.6444064378738403
# stock market 8.08
# Accordings to embeddings 0.6230741739273071
# planet constellation 8.06
# Accordings to embeddings 0.2667843699455261
# credit card 8.06
# Accordings to embeddings 0.5569600462913513
# hotel reservation 8.03
# Accordings to embeddings 0.4493829607963562
# closet clothes 8.00
# Accordings to embeddings 0.5487182140350342
# soap opera 7.94
# Accordings to embeddings 0.3187529146671295
# planet astronomer 7.94
# Accordings to embeddings 0.2698037922382355
# planet space 7.92
# Accordings to embeddings 0.6133742928504944
# movie theater 7.92
# Accordings to embeddings 0.593218207359314
# treatment recovery 7.91
# Accordings to embeddings 0.4160381257534027
# baby mother 7.85
# Accordings to embeddings 0.6791931390762329
# money deposit 7.73
# Accordings to embeddings 0.5185166001319885
# television film 7.72
# Accordings to embeddings 0.5116603374481201
# psychology mind 7.69
# Accordings to embeddings 0.44940802454948425
# game team 7.69
# Accordings to embeddings 0.5988360047340393
# admission ticket 7.69
# Accordings to embeddings 0.47301173210144043
# Jerusalem Palestinian 7.65
# Accordings to embeddings 0.5989168882369995
# Arafat terror 7.65
# Accordings to embeddings 0.1865188479423523
# boxing round 7.61
# Accordings to embeddings 0.35097384452819824
# computer internet 7.58
# Accordings to embeddings 0.55473393201828
# money property 7.57
# Accordings to embeddings 0.5266191959381104
# tennis racket 7.56
# Accordings to embeddings 0.4791463613510132
# telephone communication 7.50
# Accordings to embeddings 0.4597976505756378
# currency market 7.50
# Accordings to embeddings 0.6042878031730652
# psychology cognition 7.48
# Accordings to embeddings 0.5267143249511719
# seafood sea 7.47
# Accordings to embeddings 0.35057204961776733
# book paper 7.46
# Accordings to embeddings 0.47177374362945557
# book library 7.46
# Accordings to embeddings 0.45767176151275635
# psychology depression 7.42
# Accordings to embeddings 0.46270307898521423
# fighting defeating 7.41
# Accordings to embeddings 0.6491060256958008
# movie star 7.38
# Accordings to embeddings 0.4587670564651489
# hundred percent 7.38
# Accordings to embeddings 0.5991724133491516
# dollar profit 7.38
# Accordings to embeddings 0.6243990659713745
# money possession 7.29
# Accordings to embeddings 0.3209403157234192
# cup drink 7.25
# Accordings to embeddings 0.5357565879821777
# psychology health 7.23
# Accordings to embeddings 0.3811390995979309
# summer drought 7.16
# Accordings to embeddings 0.4143869876861572
# investor earning 7.13
# Accordings to embeddings 0.41596126556396484
# company stock 7.08
# Accordings to embeddings 0.49175041913986206
# stroke hospital 7.03
# Accordings to embeddings 0.3779603838920593
# liability insurance 7.03
# Accordings to embeddings 0.6717537045478821
# game victory 7.03
# Accordings to embeddings 0.42753922939300537
# psychology anxiety 7.00
# Accordings to embeddings 0.43841618299484253
# game defeat 6.97
# Accordings to embeddings 0.35886040329933167
# FBI fingerprint 6.94
# Accordings to embeddings 0.2655099928379059
# money withdrawal 6.88
# Accordings to embeddings 0.31612223386764526
# psychology fear 6.85
# Accordings to embeddings 0.37764644622802734
# drug abuse 6.85
# Accordings to embeddings 0.5673398971557617
# concert virtuoso 6.81
# Accordings to embeddings 0.23454637825489044
# computer laboratory 6.78
# Accordings to embeddings 0.33566930890083313
# love sex 6.77
# Accordings to embeddings 0.414214551448822
# problem challenge 6.75
# Accordings to embeddings 0.43239086866378784
# movie critic 6.73
# Accordings to embeddings 0.3923792541027069
# Arafat peace 6.73
# Accordings to embeddings 0.26838061213493347
# bed closet 6.72
# Accordings to embeddings 0.5562937259674072
# lawyer evidence 6.69
# Accordings to embeddings 0.48127925395965576
# fertility egg 6.69
# Accordings to embeddings 0.315849632024765
# precedent law 6.65
# Accordings to embeddings 0.6318640112876892
# minister party 6.63
# Accordings to embeddings 0.3804333806037903
# psychology clinic 6.58
# Accordings to embeddings 0.33812177181243896
# cup coffee 6.58
# Accordings to embeddings 0.6021322011947632
# water seepage 6.56
# Accordings to embeddings 0.2146860808134079
# government crisis 6.56
# Accordings to embeddings 0.5117059350013733
# space world 6.53
# Accordings to embeddings 0.5553286671638489
# dividend calculation 6.48
# Accordings to embeddings 0.3701329231262207
# victim emergency 6.47
# Accordings to embeddings 0.36241278052330017
# luxury car 6.47
# Accordings to embeddings 0.4845902621746063
# tool implement 6.46
# Accordings to embeddings 0.457950621843338
# competition price 6.44
# Accordings to embeddings 0.46405482292175293
# psychology doctor 6.42
# Accordings to embeddings 0.36551594734191895
# gender equality 6.41
# Accordings to embeddings 0.6433053612709045
# listing category 6.38
# Accordings to embeddings 0.5253037810325623
# video archive 6.34
# Accordings to embeddings 0.37838444113731384
# oil stock 6.34
# Accordings to embeddings 0.45026397705078125
# governor office 6.34
# Accordings to embeddings 0.4381258487701416
# discovery space 6.34
# Accordings to embeddings 0.398073673248291
# record number 6.31
# Accordings to embeddings 0.579358696937561
# brother monk 6.27
# Accordings to embeddings 0.24891729652881622
# production crew 6.25
# Accordings to embeddings 0.3623971939086914
# nature man 6.25
# Accordings to embeddings 0.37012797594070435
# family planning 6.25
# Accordings to embeddings 0.49481287598609924
# disaster area 6.25
# Accordings to embeddings 0.34139353036880493
# food preparation 6.22
# Accordings to embeddings 0.45164021849632263
# preservation world 6.19
# Accordings to embeddings 0.30240094661712646
# movie popcorn 6.19
# Accordings to embeddings 0.3923562169075012
# lover quarrel 6.19
# Accordings to embeddings 0.28065088391304016
# game series 6.19
# Accordings to embeddings 0.5303841233253479
# dollar loss 6.09
# Accordings to embeddings 0.41328737139701843
# weapon secret 6.06
# Accordings to embeddings 0.3223896622657776
# shower flood 6.03
# Accordings to embeddings 0.30699172616004944
# registration arrangement 6.00
# Accordings to embeddings 0.1833914816379547
# arrival hotel 6.00
# Accordings to embeddings 0.4280942380428314
# announcement warning 6.00
# Accordings to embeddings 0.4492342472076416
# game round 5.97
# Accordings to embeddings 0.4551377296447754
# baseball season 5.97
# Accordings to embeddings 0.4310280382633209
# drink mouth 5.96
# Accordings to embeddings 0.48751798272132874
# life lesson 5.94
# Accordings to embeddings 0.5202283263206482
# grocery money 5.94
# Accordings to embeddings 0.37592369318008423
# energy crisis 5.94
# Accordings to embeddings 0.31536006927490234
# reason criterion 5.91
# Accordings to embeddings 0.2541271150112152
# equipment maker 5.91
# Accordings to embeddings 0.39825043082237244
# cup liquid 5.90
# Accordings to embeddings 0.42607811093330383
# deployment withdrawal 5.88
# Accordings to embeddings 0.2613605856895447
# tiger zoo 5.87
# Accordings to embeddings 0.4152815341949463
# journey car 5.85
# Accordings to embeddings 0.30110132694244385
# money laundering 5.65
# Accordings to embeddings 0.472147136926651
# summer nature 5.63
# Accordings to embeddings 0.28468215465545654
# decoration valor 5.63
# Accordings to embeddings 0.1627604365348816
# Mars scientist 5.63
# Accordings to embeddings 0.3546523153781891
# alcohol chemistry 5.54
# Accordings to embeddings 0.3194279968738556
# disability death 5.47
# Accordings to embeddings 0.31799784302711487
# change attitude 5.44
# Accordings to embeddings 0.5161808133125305
# arrangement accommodation 5.41
# Accordings to embeddings 0.42552992701530457
# territory surface 5.34
# Accordings to embeddings 0.30197495222091675
# size prominence 5.31
# Accordings to embeddings 0.1626611351966858
# exhibit memorabilia 5.31
# Accordings to embeddings 0.28474143147468567
# credit information 5.31
# Accordings to embeddings 0.4734674096107483
# territory kilometer 5.28
# Accordings to embeddings 0.2339308112859726
# death row 5.25
# Accordings to embeddings 0.33835741877555847
# doctor liability 5.19
# Accordings to embeddings 0.2892354726791382
# impartiality interest 5.16
# Accordings to embeddings 0.21482345461845398
# energy laboratory 5.09
# Accordings to embeddings 0.24916942417621613
# secretary senate 5.06
# Accordings to embeddings 0.3915354609489441
# death inmate 5.03
# Accordings to embeddings 0.32272276282310486
# monk oracle 5.00
# Accordings to embeddings 0.28416910767555237
# cup food 5.00
# Accordings to embeddings 0.3961872160434723
# journal association 4.97
# Accordings to embeddings 0.35200610756874084
# street children 4.94
# Accordings to embeddings 0.4076368808746338
# car flight 4.94
# Accordings to embeddings 0.35694918036460876
# space chemistry 4.88
# Accordings to embeddings 0.24976733326911926
# situation conclusion 4.81
# Accordings to embeddings 0.5924026370048523
# word similarity 4.75
# Accordings to embeddings 0.35383546352386475
# peace plan 4.75
# Accordings to embeddings 0.38898661732673645
# consumer energy 4.75
# Accordings to embeddings 0.34588244557380676
# ministry culture 4.69
# Accordings to embeddings 0.20008563995361328
# smart student 4.62
# Accordings to embeddings 0.41547632217407227
# investigation effort 4.59
# Accordings to embeddings 0.4004097580909729
# image surface 4.56
# Accordings to embeddings 0.43039366602897644
# life term 4.50
# Accordings to embeddings 0.5220338106155396
# start match 4.47
# Accordings to embeddings 0.4437134563922882
# computer news 4.47
# Accordings to embeddings 0.3207775056362152
# board recommendation 4.47
# Accordings to embeddings 0.4164328873157501
# lad brother 4.46
# Accordings to embeddings 0.43826285004615784
# observation architecture 4.38
# Accordings to embeddings 0.3174193501472473
# coast hill 4.38
# Accordings to embeddings 0.416038453578949
# deployment departure 4.25
# Accordings to embeddings 0.25761979818344116
# benchmark index 4.25
# Accordings to embeddings 0.39395010471343994
# attempt peace 4.25
# Accordings to embeddings 0.41809573769569397
# consumer confidence 4.13
# Accordings to embeddings 0.31818991899490356
# start year 4.06
# Accordings to embeddings 0.5728110671043396
# focus life 4.06
# Accordings to embeddings 0.5593059062957764
# development issue 3.97
# Accordings to embeddings 0.4772372543811798
# theater history 3.91
# Accordings to embeddings 0.3190425634384155
# situation isolation 3.88
# Accordings to embeddings 0.39292529225349426
# profit warning 3.88
# Accordings to embeddings 0.27012157440185547
# media trading 3.88
# Accordings to embeddings 0.25307804346084595
# chance credibility 3.88
# Accordings to embeddings 0.37108922004699707
# precedent information 3.85
# Accordings to embeddings 0.3611895442008972
# architecture century 3.78
# Accordings to embeddings 0.3951128423213959
# population development 3.75
# Accordings to embeddings 0.39288169145584106
# stock live 3.73
# Accordings to embeddings 0.32400715351104736
# peace atmosphere 3.69
# Accordings to embeddings 0.25215113162994385
# morality marriage 3.69
# Accordings to embeddings 0.46056878566741943
# minority peace 3.69
# Accordings to embeddings 0.3881843686103821
# atmosphere landscape 3.69
# Accordings to embeddings 0.3972983658313751
# report gain 3.63
# Accordings to embeddings 0.3547426760196686
# music project 3.63
# Accordings to embeddings 0.4130692481994629
# seven series 3.56
# Accordings to embeddings 0.4130992293357849
# experience music 3.47
# Accordings to embeddings 0.4603627622127533
# school center 3.44
# Accordings to embeddings 0.42020076513290405
# five month 3.38
# Accordings to embeddings 0.6414780020713806
# announcement production 3.38
# Accordings to embeddings 0.3201535642147064
# morality importance 3.31
# Accordings to embeddings 0.4890907108783722
# money operation 3.31
# Accordings to embeddings 0.40730777382850647
# delay news 3.31
# Accordings to embeddings 0.34936538338661194
# governor interview 3.25
# Accordings to embeddings 0.23201020061969757
# practice institution 3.19
# Accordings to embeddings 0.3979455828666687
# century nation 3.16
# Accordings to embeddings 0.5300995707511902
# coast forest 3.15
# Accordings to embeddings 0.3807464838027954
# shore woodland 3.08
# Accordings to embeddings 0.20673906803131104
# drink car 3.04
# Accordings to embeddings 0.3421905040740967
# president medal 3.00
# Accordings to embeddings 0.28491833806037903
# prejudice recognition 3.00
# Accordings to embeddings 0.3423425853252411
# viewer serial 2.97
# Accordings to embeddings 0.24693569540977478
# peace insurance 2.94
# Accordings to embeddings 0.2724657952785492
# Mars water 2.94
# Accordings to embeddings 0.2957363426685333
# media gain 2.88
# Accordings to embeddings 0.3722897469997406
# precedent cognition 2.81
# Accordings to embeddings 0.12062067538499832
# announcement effort 2.75
# Accordings to embeddings 0.38093340396881104
# line insurance 2.69
# Accordings to embeddings 0.3195638358592987
# crane implement 2.69
# Accordings to embeddings 0.15929584205150604
# drink mother 2.65
# Accordings to embeddings 0.37800756096839905
# opera industry 2.63
# Accordings to embeddings 0.23756881058216095
# volunteer motto 2.56
# Accordings to embeddings 0.2704891860485077
# listing proximity 2.56
# Accordings to embeddings 0.2339887022972107
# precedent collection 2.50
# Accordings to embeddings 0.24662278592586517
# cup article 2.40
# Accordings to embeddings 0.2328190952539444
# sign recess 2.38
# Accordings to embeddings 0.13012780249118805
# problem airport 2.38
# Accordings to embeddings 0.3041805326938629
# reason hypertension 2.31
# Accordings to embeddings 0.10676650702953339
# direction combination 2.25
# Accordings to embeddings 0.4754093885421753
# Wednesday news 2.22
# Accordings to embeddings 0.48079678416252136
# glass magician 2.08
# Accordings to embeddings 0.20556864142417908
# cemetery woodland 2.08
# Accordings to embeddings 0.34855765104293823
# possibility girl 1.94
# Accordings to embeddings 0.4071235954761505
# cup substance 1.92
# Accordings to embeddings 0.2686023712158203
# forest graveyard 1.85
# Accordings to embeddings 0.3066401183605194
# stock egg 1.81
# Accordings to embeddings 0.31627780199050903
# month hotel 1.81
# Accordings to embeddings 0.40488505363464355
# energy secretary 1.81
# Accordings to embeddings 0.18707945942878723
# precedent group 1.77
# Accordings to embeddings 0.24936993420124054
# production hike 1.75
# Accordings to embeddings 0.16242899000644684
# stock phone 1.62
# Accordings to embeddings 0.41234278678894043
# holy sex 1.62
# Accordings to embeddings 0.3487611711025238
# stock CD 1.31
# Accordings to embeddings 0.24401775002479553
# drink ear 1.31
# Accordings to embeddings 0.2767912447452545
# delay racism 1.19
# Accordings to embeddings 0.17487025260925293
# stock life 0.92
# Accordings to embeddings 0.3764672577381134
# stock jaguar 0.92
# Accordings to embeddings 0.13652171194553375
# monk slave 0.92
# Accordings to embeddings 0.21549420058727264
# lad wizard 0.92
# Accordings to embeddings 0.24018077552318573
# sugar approach 0.88
# Accordings to embeddings 0.26019927859306335
# rooster voyage 0.62
# Accordings to embeddings 0.04208751022815704
# noon string 0.54
# Accordings to embeddings 0.12752383947372437
# chord smile 0.54
# Accordings to embeddings 0.11598864942789078
# professor cucumber 0.31
# Accordings to embeddings 0.09292452782392502
# king cabbage 0.23
# Accordings to embeddings 0.19204890727996826
# Final average abs deviation: 0.18272506468612992

# %%
test_embeddings_wordsim(model)
# Out:
# computer keyboard 7.62
# Accordings to embeddings 0.3963916301727295
# Jerusalem Israel 8.46
# Accordings to embeddings 0.6638747453689575
# planet galaxy 8.11
# Accordings to embeddings 0.6338510513305664
# canyon landscape 7.53
# Accordings to embeddings 0.24369587004184723
# OPEC country 5.63
# Accordings to embeddings 0.1194893941283226
# day summer 3.94
# Accordings to embeddings 0.4481317102909088
# day dawn 7.53
# Accordings to embeddings 0.331085741519928
# country citizen 7.31
# Accordings to embeddings 0.20985937118530273
# planet people 5.75
# Accordings to embeddings 0.08704742044210434
# environment ecology 8.81
# Accordings to embeddings 0.4299762547016144
# Maradona football 8.62
# Accordings to embeddings 0.28883832693099976
# OPEC oil 8.59
# Accordings to embeddings 0.5333777666091919
# money bank 8.50
# Accordings to embeddings 0.2613206207752228
# computer software 8.50
# Accordings to embeddings 0.5444108843803406
# law lawyer 8.38
# Accordings to embeddings 0.34465768933296204
# weather forecast 8.34
# Accordings to embeddings 0.3627207279205322
# network hardware 8.31
# Accordings to embeddings 0.29377812147140503
# nature environment 8.31
# Accordings to embeddings 0.40284886956214905
# FBI investigation 8.31
# Accordings to embeddings 0.4171353280544281
# money wealth 8.27
# Accordings to embeddings 0.329510360956192
# psychology Freud 8.21
# Accordings to embeddings 0.33308249711990356
# news report 8.16
# Accordings to embeddings 0.3123636245727539
# war troops 8.13
# Accordings to embeddings 0.47614771127700806
# physics proton 8.12
# Accordings to embeddings 0.3664059638977051
# bank money 8.12
# Accordings to embeddings 0.2613206207752228
# stock market 8.08
# Accordings to embeddings 0.4680555760860443
# planet constellation 8.06
# Accordings to embeddings 0.39312949776649475
# credit card 8.06
# Accordings to embeddings 0.2681569457054138
# hotel reservation 8.03
# Accordings to embeddings 0.3028254210948944
# closet clothes 8.00
# Accordings to embeddings 0.41773033142089844
# soap opera 7.94
# Accordings to embeddings 0.1955799162387848
# planet astronomer 7.94
# Accordings to embeddings 0.30787548422813416
# planet space 7.92
# Accordings to embeddings 0.28036749362945557
# movie theater 7.92
# Accordings to embeddings 0.47419047355651855
# treatment recovery 7.91
# Accordings to embeddings 0.2493065893650055
# baby mother 7.85
# Accordings to embeddings 0.5839769840240479
# money deposit 7.73
# Accordings to embeddings 0.2604113221168518
# television film 7.72
# Accordings to embeddings 0.34557002782821655
# psychology mind 7.69
# Accordings to embeddings 0.25049889087677
# game team 7.69
# Accordings to embeddings 0.496656209230423
# admission ticket 7.69
# Accordings to embeddings 0.43688318133354187
# Jerusalem Palestinian 7.65
# Accordings to embeddings 0.6342511773109436
# Arafat terror 7.65
# Accordings to embeddings 0.3215480446815491
# boxing round 7.61
# Accordings to embeddings 0.177592471241951
# computer internet 7.58
# Accordings to embeddings 0.4068623185157776
# money property 7.57
# Accordings to embeddings 0.26824459433555603
# tennis racket 7.56
# Accordings to embeddings 0.3920080065727234
# telephone communication 7.50
# Accordings to embeddings 0.3321845531463623
# currency market 7.50
# Accordings to embeddings 0.3382996618747711
# psychology cognition 7.48
# Accordings to embeddings 0.3995116353034973
# seafood sea 7.47
# Accordings to embeddings 0.31509068608283997
# book paper 7.46
# Accordings to embeddings 0.3634625971317291
# book library 7.46
# Accordings to embeddings 0.3245311975479126
# psychology depression 7.42
# Accordings to embeddings 0.3135565519332886
# fighting defeating 7.41
# Accordings to embeddings 0.3445202708244324
# movie star 7.38
# Accordings to embeddings 0.26419904828071594
# hundred percent 7.38
# Accordings to embeddings 0.18021871149539948
# dollar profit 7.38
# Accordings to embeddings 0.25337404012680054
# money possession 7.29
# Accordings to embeddings 0.0531826987862587
# cup drink 7.25
# Accordings to embeddings 0.35322171449661255
# psychology health 7.23
# Accordings to embeddings 0.17619234323501587
# summer drought 7.16
# Accordings to embeddings 0.1637890487909317
# investor earning 7.13
# Accordings to embeddings 0.0034081488847732544
# company stock 7.08
# Accordings to embeddings 0.3415686786174774
# stroke hospital 7.03
# Accordings to embeddings 0.23570409417152405
# liability insurance 7.03
# Accordings to embeddings 0.45244452357292175
# game victory 7.03
# Accordings to embeddings 0.3314371407032013
# psychology anxiety 7.00
# Accordings to embeddings 0.2719925045967102
# game defeat 6.97
# Accordings to embeddings 0.3329892158508301
# FBI fingerprint 6.94
# Accordings to embeddings 0.3378998041152954
# money withdrawal 6.88
# Accordings to embeddings 0.05602632835507393
# psychology fear 6.85
# Accordings to embeddings 0.17129428684711456
# drug abuse 6.85
# Accordings to embeddings 0.24085767567157745
# concert virtuoso 6.81
# Accordings to embeddings 0.28570184111595154
# computer laboratory 6.78
# Accordings to embeddings 0.2875465452671051
# love sex 6.77
# Accordings to embeddings 0.26393771171569824
# problem challenge 6.75
# Accordings to embeddings 0.4629537761211395
# movie critic 6.73
# Accordings to embeddings 0.17430327832698822
# Arafat peace 6.73
# Accordings to embeddings 0.31498634815216064
# bed closet 6.72
# Accordings to embeddings 0.4319477081298828
# lawyer evidence 6.69
# Accordings to embeddings 0.198607936501503
# fertility egg 6.69
# Accordings to embeddings 0.256523460149765
# precedent law 6.65
# Accordings to embeddings 0.34597012400627136
# minister party 6.63
# Accordings to embeddings 0.1715518683195114
# psychology clinic 6.58
# Accordings to embeddings 0.12102103233337402
# cup coffee 6.58
# Accordings to embeddings 0.3560177683830261
# water seepage 6.56
# Accordings to embeddings 0.39313429594039917
# government crisis 6.56
# Accordings to embeddings 0.29561758041381836
# space world 6.53
# Accordings to embeddings 0.1296270787715912
# dividend calculation 6.48
# Accordings to embeddings 0.15065297484397888
# victim emergency 6.47
# Accordings to embeddings 0.17580635845661163
# luxury car 6.47
# Accordings to embeddings 0.2445117086172104
# tool implement 6.46
# Accordings to embeddings 0.2123422920703888
# competition price 6.44
# Accordings to embeddings 0.17668063938617706
# psychology doctor 6.42
# Accordings to embeddings 0.19066521525382996
# gender equality 6.41
# Accordings to embeddings 0.5059923529624939
# listing category 6.38
# Accordings to embeddings 0.11038407683372498
# video archive 6.34
# Accordings to embeddings 0.17350751161575317
# oil stock 6.34
# Accordings to embeddings 0.2203982025384903
# governor office 6.34
# Accordings to embeddings 0.29663559794425964
# discovery space 6.34
# Accordings to embeddings 0.041256409138441086
# record number 6.31
# Accordings to embeddings 0.22208687663078308
# brother monk 6.27
# Accordings to embeddings 0.22320020198822021
# production crew 6.25
# Accordings to embeddings 0.17930838465690613
# nature man 6.25
# Accordings to embeddings 0.11616960912942886
# family planning 6.25
# Accordings to embeddings 0.1914883404970169
# disaster area 6.25
# Accordings to embeddings 0.145228311419487
# food preparation 6.22
# Accordings to embeddings 0.17799316346645355
# preservation world 6.19
# Accordings to embeddings -0.02147061750292778
# movie popcorn 6.19
# Accordings to embeddings 0.44535526633262634
# lover quarrel 6.19
# Accordings to embeddings 0.23226581513881683
# game series 6.19
# Accordings to embeddings 0.29130783677101135
# dollar loss 6.09
# Accordings to embeddings 0.026566721498966217
# weapon secret 6.06
# Accordings to embeddings 0.2584390342235565
# shower flood 6.03
# Accordings to embeddings 0.12947934865951538
# registration arrangement 6.00
# Accordings to embeddings 0.11914841830730438
# arrival hotel 6.00
# Accordings to embeddings 0.1593550145626068
# announcement warning 6.00
# Accordings to embeddings 0.24619008600711823
# game round 5.97
# Accordings to embeddings 0.2722221314907074
# baseball season 5.97
# Accordings to embeddings 0.2622438371181488
# drink mouth 5.96
# Accordings to embeddings 0.17304003238677979
# life lesson 5.94
# Accordings to embeddings 0.19252909719944
# grocery money 5.94
# Accordings to embeddings 0.12704519927501678
# energy crisis 5.94
# Accordings to embeddings 0.13847880065441132
# reason criterion 5.91
# Accordings to embeddings 0.3923366069793701
# equipment maker 5.91
# Accordings to embeddings 0.20798198878765106
# cup liquid 5.90
# Accordings to embeddings 0.25183939933776855
# deployment withdrawal 5.88
# Accordings to embeddings 0.40605056285858154
# tiger zoo 5.87
# Accordings to embeddings 0.46924546360969543
# journey car 5.85
# Accordings to embeddings 0.09849625080823898
# money laundering 5.65
# Accordings to embeddings 0.2523637115955353
# summer nature 5.63
# Accordings to embeddings 0.12260760366916656
# decoration valor 5.63
# Accordings to embeddings 0.322715699672699
# Mars scientist 5.63
# Accordings to embeddings 0.17972104251384735
# alcohol chemistry 5.54
# Accordings to embeddings 0.08876198530197144
# disability death 5.47
# Accordings to embeddings 0.27521100640296936
# change attitude 5.44
# Accordings to embeddings 0.2514270544052124
# arrangement accommodation 5.41
# Accordings to embeddings 0.2305612415075302
# territory surface 5.34
# Accordings to embeddings 0.1395847201347351
# size prominence 5.31
# Accordings to embeddings 0.1337670534849167
# exhibit memorabilia 5.31
# Accordings to embeddings 0.302592933177948
# credit information 5.31
# Accordings to embeddings 0.11662980169057846
# territory kilometer 5.28
# Accordings to embeddings 0.154084250330925
# death row 5.25
# Accordings to embeddings 0.1561248004436493
# doctor liability 5.19
# Accordings to embeddings 0.061160389333963394
# impartiality interest 5.16
# Accordings to embeddings 0.20375370979309082
# energy laboratory 5.09
# Accordings to embeddings 0.11277152597904205
# secretary senate 5.06
# Accordings to embeddings 0.23210787773132324
# death inmate 5.03
# Accordings to embeddings 0.2757277488708496
# monk oracle 5.00
# Accordings to embeddings 0.30354034900665283
# cup food 5.00
# Accordings to embeddings 0.09379564970731735
# journal association 4.97
# Accordings to embeddings 0.16295818984508514
# street children 4.94
# Accordings to embeddings 0.15370696783065796
# car flight 4.94
# Accordings to embeddings 0.14423443377017975
# space chemistry 4.88
# Accordings to embeddings 0.0802517682313919
# situation conclusion 4.81
# Accordings to embeddings 0.1847420483827591
# word similarity 4.75
# Accordings to embeddings 0.09658685326576233
# peace plan 4.75
# Accordings to embeddings 0.11900727450847626
# consumer energy 4.75
# Accordings to embeddings 0.2461671382188797
# ministry culture 4.69
# Accordings to embeddings 0.1877954751253128
# smart student 4.62
# Accordings to embeddings 0.06630215793848038
# investigation effort 4.59
# Accordings to embeddings 0.23487992584705353
# image surface 4.56
# Accordings to embeddings 0.12843585014343262
# life term 4.50
# Accordings to embeddings 0.2267606109380722
# start match 4.47
# Accordings to embeddings 0.24805229902267456
# computer news 4.47
# Accordings to embeddings 0.1039980947971344
# board recommendation 4.47
# Accordings to embeddings 0.321181058883667
# lad brother 4.46
# Accordings to embeddings 0.3595924973487854
# observation architecture 4.38
# Accordings to embeddings 0.13629396259784698
# coast hill 4.38
# Accordings to embeddings 0.1611577421426773
# deployment departure 4.25
# Accordings to embeddings 0.2766171395778656
# benchmark index 4.25
# Accordings to embeddings 0.49516886472702026
# attempt peace 4.25
# Accordings to embeddings 0.06137871369719505
# consumer confidence 4.13
# Accordings to embeddings 0.19126538932323456
# start year 4.06
# Accordings to embeddings 0.1901860237121582
# focus life 4.06
# Accordings to embeddings 0.14205680787563324
# development issue 3.97
# Accordings to embeddings 0.09010776877403259
# theater history 3.91
# Accordings to embeddings 0.12982812523841858
# situation isolation 3.88
# Accordings to embeddings 0.20984452962875366
# profit warning 3.88
# Accordings to embeddings 0.13709336519241333
# media trading 3.88
# Accordings to embeddings 0.12612037360668182
# chance credibility 3.88
# Accordings to embeddings 0.23921893537044525
# precedent information 3.85
# Accordings to embeddings 0.08866602927446365
# architecture century 3.78
# Accordings to embeddings 0.1430933028459549
# population development 3.75
# Accordings to embeddings 0.17502304911613464
# stock live 3.73
# Accordings to embeddings 0.044471774250268936
# peace atmosphere 3.69
# Accordings to embeddings 0.13366279006004333
# morality marriage 3.69
# Accordings to embeddings 0.30624133348464966
# minority peace 3.69
# Accordings to embeddings 0.06868558377027512
# atmosphere landscape 3.69
# Accordings to embeddings 0.2697125971317291
# report gain 3.63
# Accordings to embeddings 0.09995908290147781
# music project 3.63
# Accordings to embeddings 0.02134612575173378
# seven series 3.56
# Accordings to embeddings 0.33100616931915283
# experience music 3.47
# Accordings to embeddings 0.16575714945793152
# school center 3.44
# Accordings to embeddings 0.14268212020397186
# five month 3.38
# Accordings to embeddings 0.40400832891464233
# announcement production 3.38
# Accordings to embeddings 0.08066592365503311
# morality importance 3.31
# Accordings to embeddings 0.2053404003381729
# money operation 3.31
# Accordings to embeddings 0.0845692828297615
# delay news 3.31
# Accordings to embeddings 0.12586815655231476
# governor interview 3.25
# Accordings to embeddings 0.11880448460578918
# practice institution 3.19
# Accordings to embeddings 0.09677621722221375
# century nation 3.16
# Accordings to embeddings 0.2919147312641144
# coast forest 3.15
# Accordings to embeddings 0.23609787225723267
# shore woodland 3.08
# Accordings to embeddings 0.116909459233284
# drink car 3.04
# Accordings to embeddings 0.24563539028167725
# president medal 3.00
# Accordings to embeddings 0.06946567445993423
# prejudice recognition 3.00
# Accordings to embeddings 0.11657062917947769
# viewer serial 2.97
# Accordings to embeddings 0.23336465656757355
# peace insurance 2.94
# Accordings to embeddings 0.09818775951862335
# Mars water 2.94
# Accordings to embeddings 0.13637156784534454
# media gain 2.88
# Accordings to embeddings 0.10171882808208466
# precedent cognition 2.81
# Accordings to embeddings -0.020569603890180588
# announcement effort 2.75
# Accordings to embeddings 0.23130612075328827
# line insurance 2.69
# Accordings to embeddings 0.08391069620847702
# crane implement 2.69
# Accordings to embeddings 0.023186156526207924
# drink mother 2.65
# Accordings to embeddings 0.15679939091205597
# opera industry 2.63
# Accordings to embeddings 0.04291350394487381
# volunteer motto 2.56
# Accordings to embeddings 0.1912766546010971
# listing proximity 2.56
# Accordings to embeddings 0.123604416847229
# precedent collection 2.50
# Accordings to embeddings 0.03283146023750305
# cup article 2.40
# Accordings to embeddings 0.08339213579893112
# sign recess 2.38
# Accordings to embeddings 0.048051152378320694
# problem airport 2.38
# Accordings to embeddings 0.10208498686552048
# reason hypertension 2.31
# Accordings to embeddings 0.07555148750543594
# direction combination 2.25
# Accordings to embeddings 0.09585042297840118
# Wednesday news 2.22
# Accordings to embeddings 0.2601482570171356
# glass magician 2.08
# Accordings to embeddings 0.0372249111533165
# cemetery woodland 2.08
# Accordings to embeddings 0.3819250166416168
# possibility girl 1.94
# Accordings to embeddings 0.060037761926651
# cup substance 1.92
# Accordings to embeddings 0.12556417286396027
# forest graveyard 1.85
# Accordings to embeddings 0.22901120781898499
# stock egg 1.81
# Accordings to embeddings 0.10417768359184265
# month hotel 1.81
# Accordings to embeddings 0.12591952085494995
# energy secretary 1.81
# Accordings to embeddings 0.09282553195953369
# precedent group 1.77
# Accordings to embeddings 0.07681482285261154
# production hike 1.75
# Accordings to embeddings 0.018261175602674484
# stock phone 1.62
# Accordings to embeddings 0.12326755374670029
# holy sex 1.62
# Accordings to embeddings 0.10070592910051346
# stock CD 1.31
# Accordings to embeddings 0.06611791253089905
# drink ear 1.31
# Accordings to embeddings 0.09346936643123627
# delay racism 1.19
# Accordings to embeddings 0.023803045973181725
# stock life 0.92
# Accordings to embeddings 0.07456466555595398
# stock jaguar 0.92
# Accordings to embeddings 0.03606690838932991
# monk slave 0.92
# Accordings to embeddings 0.19146229326725006
# lad wizard 0.92
# Accordings to embeddings 0.33023008704185486
# sugar approach 0.88
# Accordings to embeddings 0.00772056682035327
# rooster voyage 0.62
# Accordings to embeddings 0.06275808811187744
# noon string 0.54
# Accordings to embeddings 0.021654509007930756
# chord smile 0.54
# Accordings to embeddings 0.14869236946105957
# professor cucumber 0.31
# Accordings to embeddings 0.05661813169717789
# king cabbage 0.23
# Accordings to embeddings 0.11813169717788696
# Final average abs deviation: 0.31618940329109707

# %% [markdown]
# As you can see wordsim test is not very representative of the quality of embeddings. Now, let's use KNN classification on our dataset to determine the best vectors.

# %%
import pandas as pd
dataset1 = pd.read_csv('dataset/fine_grained_full.csv')
dataset2 = pd.read_csv('dataset/cleaned_all_title_data_controversial.csv')
print(dataset1.shape, dataset2.shape)
# Out:
# (429300, 2) (1000156, 2)

# %%
dataset1.head()
# Out:
#         label                                               text
# 0  studyroomf  Do you subscribe to the theory that all the ev...
# 1  studyroomf   A pivotal moment for the dean: "We love you too"
# 2  studyroomf  Episode Discussion - S04E05 - Cooperative Esca...
# 3  studyroomf  Dan Harmon says "There's a character from seas...
# 4  studyroomf  'Can we take a sidebar from this sidebar?' Sug...

# %%
import os
os.cpu_count()
# Out:
# 16

# %%
import nltk
from nltk import WordNetLemmatizer
from multiprocessing import Pool
from tqdm.notebook import tqdm
def preprocess_pipeline(dataset):
    cores = 12
    multicore_tok(dataset, cores)
    multicore_lem(dataset, cores)

def multicore_tok(dataset, cores=6):
    with Pool(processes=cores) as pool:
        dataset.loc[:, "text"] = pool.map(nltk.word_tokenize, dataset.loc[:, "text"])

def multicore_lem(dataset, cores=6):
    with Pool(processes=cores) as pool:
        wnl = WordNetLemmatizer()
        for i, line in tqdm(enumerate(dataset.text)):
            dataset.loc[i,"text"] = pool.map(wnl.lemmatize, dataset.loc[i, "text"])

# %%
preprocess_pipeline(dataset1)
print(dataset1[:4])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
